# %% [markdown]
# <a href="https://colab.research.google.com/github/yoloaryan/Pandas/blob/main/Py(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !pip install pandas

# %%
# !pip install --upgrade pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 93.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.3 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.3 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.3 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.3 which is incompatible.
# ...

# %%
labels =['a','b','c']
my_list =[10,20,30]
arr= np.array([10,20,30])
d= {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
data ={
    'Name':['John','Anna','Peter','Linda'],
    'Age': [28,34,39,42],
    'City':['New York','Paris','Berlin','London'],
    'Salary':[65000,70000,62000,85000]
}
df= pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
  ['John',28,'New York',65000],
	['Anna',34,'Paris',70000],
	['Peter',39,'Berlin',62000],
	['Linda',42,'London',85000]

]
df2= pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2=pd.DataFrame(data_list,columns=columns)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# # Selection and indexing of columns

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[0]
#--> throws an error because when we use dataframe ,columns anme came in
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3640         try:
# -> 3641             return self._engine.get_loc(casted_key)
#    3642         except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_828/4226446734.py in <cell line: 0>()
# ----> 1 df2[0]
#       2 #--> throws an error because when we use dataframe ,columns anme came in
#
# ...

# %%
df2['Age']
# Out:
# 0    28
# 1    34
# 2    39
# 3    42
# Name: Age, dtype: int64

# %%
df2['Salary']
# Out:
# 0    65000
# 1    70000
# 2    62000
# 3    85000
# Name: Salary, dtype: int64

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating a new columns

# %%
df2["Designition"] = ["Doctor","Eng.","Doctor","Eng."]

# %%
df2
# Out:
#     Name  Age      City  Salary Designition
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   39    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %% [markdown]
# Removing columns

# %%
df2.drop('Designition',axis = 1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary Designition
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   39    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df2.drop('Designition',axis=1,inplace= True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(["City","Salary"],axis=1)
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   39
# 3  Linda   42

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(["City","Salary"],axis =1)
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   39
# 3  Linda   42

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(0,axis = 0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   39  Berlin   62000
# 3  Linda   42  London   85000

# %% [markdown]
# # Selecting Rows

# %%
df2[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3640         try:
# -> 3641             return self._engine.get_loc(casted_key)
#    3642         except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_828/19425605.py in <cell line: 0>()
# ----> 1 df2[0]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4376             if self.columns.nlevels > 1:
# ...

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# **Selecting subsets of rows and columns**
#
#
# ---

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df.loc[[2,3],["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   39
# 3  Linda   42

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   39    Berlin   62000
# 3  Linda   42    London   85000

# %%
#only want to see those people whose age is above 30

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   39  Berlin   62000
# 3  Linda   42  London   85000

# %%
#df2[if["Age"]>30] # in pandas this is wrong

# %%
#i only want people whose age is above 30 and their city must be in paris

# %%
df2[(df2["Age"] > 30) & (df2["City"] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
